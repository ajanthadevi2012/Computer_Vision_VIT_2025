# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Collecting comtypes (from pyttsx3)
#   Downloading comtypes-1.4.13-py3-none-any.whl.metadata (7.2 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\users\ajantha\anaconda3\lib\site-packages (from pyttsx3) (305.1)
# Downloading pyttsx3-2.99-py3-none-any.whl (32 kB)
# Downloading comtypes-1.4.13-py3-none-any.whl (254 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: pypiwin32, comtypes, pyttsx3
# Successfully installed comtypes-1.4.13 pypiwin32-223 pyttsx3-2.99
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3
engine = pyttsx3.init()
rate =  engine.getProperty('rate')
engine.setProperty('rate',100)
volume = engine.getProperty('volume')
engine.setProperty('volume',1.0)
#engine.setProperty('voice','english')
voice = engine.getProperty('voices')
engine.setProperty('voice',voice[1].id)
engine.say("welcome to todays session. hope everyone enjoyed and learned a new thing")
engine.runAndWait()
